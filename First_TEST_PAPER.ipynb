# %%
import pandas as pd

# %%
Student_survey=pd.read_csv('Test01/StudentPerformanceFactors.csv.xls')
Student_survey
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
Student_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
Student_survey['School_Type'].unique()
# Out:
# array(['Public', 'Private'], dtype=object)

# %% [markdown]
# # Q1: 500-700 Students there family_income,internet_access,hours_studied and parent_involvement

# %%
Student_survey.loc[499:699,['Family_Income','Internet_Access','Hours_Studied','Parental_Involvement']]
# Out:
#     Family_Income Internet_Access  Hours_Studied Parental_Involvement
# 499        Medium             Yes             12                 High
# 500           Low             Yes             26               Medium
# 501           Low             Yes             31                 High
# 502        Medium             Yes             12               Medium
# 503          High             Yes             23               Medium
# ..            ...             ...            ...                  ...
# 695           Low             Yes             18                 High
# 696        Medium             Yes             22                 High
# 697          High              No             12                 High
# 698          High             Yes             26               Medium
# 699           Low             Yes             19               Medium
#
# [201 rows x 4 columns]

# %% [markdown]
# **TAKEAWAY :  The info of the students 500-700**

# %% [markdown]
# # Q2 : 1000-1100 students take all the numerical features

# %%
Student_survey.select_dtypes(int,float)
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6602             25          69            7               76
# 6603             23          76            8               81
# 6604             20          90            6               65
# 6605             10          86            6               91
# 6606             15          67            9               94
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score
# 0                     0                  3          67
# 1                     2                  4          61
# ...

# %% [markdown]
# **TAKEAWAY : There are 7 columns which contains numerical values**

# %% [markdown]
# # Q3: 3000-3500 Students largest time taken to study

# %%
A=Student_survey.loc[2999:3499,['Hours_Studied','Attendance']]
A.sort_values(by='Hours_Studied',ascending=False)
# Out:
#       Hours_Studied  Attendance
# 3241             37          96
# 3192             34          96
# 3319             34          84
# 3398             34          77
# 3434             34          93
# ...             ...         ...
# 3405              5          95
# 3481              4          76
# 3017              3          83
# 3152              3          92
# 3454              2          99
#
# [501 rows x 2 columns]

# %% [markdown]
# **TAKEAWAY : These are the results of top hours studied of the students 3000-3500**

# %% [markdown]
# # Q4 : Take Extraccuricular column make it in int

# %%
Student_survey['Extracurricular_Activities'].dtype
# Out:
# dtype('O')

# %%
Student_survey['Extracurricular_Activities']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 6602     No
# 6603     No
# 6604    Yes
# 6605    Yes
# 6606    Yes
# Name: Extracurricular_Activities, Length: 6607, dtype: object

# %%
Student_survey['Extracurricular_Activities'].map({'Yes':1,'No':0})
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 6602    0
# 6603    0
# 6604    1
# 6605    1
# 6606    1
# Name: Extracurricular_Activities, Length: 6607, dtype: int64

# %% [markdown]
# # Q5:Low Parent involvement and having low attendence

# %%
Student_survey.sort_values(by=['Parental_Involvement','Attendance'],ascending=[False,True]).loc[:,['Parental_Involvement','Attendance']]
# Out:
#      Parental_Involvement  Attendance
# 16                 Medium          60
# 290                Medium          60
# 483                Medium          60
# 573                Medium          60
# 594                Medium          60
# ...                   ...         ...
# 5976                 High         100
# 6040                 High         100
# 6081                 High         100
# 6310                 High         100
# 6359                 High         100
#
# [6607 rows x 2 columns]

# %% [markdown]
# # Q06 - How can you sort the Student_survey DataFrame by the Distance_from_Home column in ascending order and display only the Distance_from_Home and Attendance columns?"

# %%
Student_survey.sort_values(by='Distance_from_Home',ascending=True).loc[:,['Distance_from_Home','Attendance']]
# Out:
#      Distance_from_Home  Attendance
# 2076                Far          77
# 1403                Far          71
# 638                 Far         100
# 3319                Far          84
# 3316                Far          98
# ...                 ...         ...
# 6432                NaN          72
# 6494                NaN          77
# 6496                NaN          77
# 6589                NaN          90
# 6594                NaN          90
#
# [6607 rows x 2 columns]

# %%
Student_survey['Teacher_Quality'].unique
# Out:
# <bound method Series.unique of 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 6602    Medium
# 6603      High
# 6604    Medium
# 6605    Medium
# 6606    Medium
# Name: Teacher_Quality, Length: 6607, dtype: object>

# %% [markdown]
# # Q7:How can we filter the Student_survey DataFrame to display the School_Type, Teacher_Quality, and Attendance columns for students who either attend a public school or have high teacher quality?

# %%
Student_survey.loc[(Student_survey['School_Type']=='Public')|(Student_survey['Teacher_Quality']=='High')].loc[:,['School_Type','Teacher_Quality','Attendance']]
# Out:
#      School_Type Teacher_Quality  Attendance
# 0         Public          Medium          84
# 1         Public          Medium          64
# 2         Public          Medium          98
# 3         Public          Medium          89
# 4         Public            High          92
# ...          ...             ...         ...
# 6601      Public          Medium          83
# 6602      Public          Medium          69
# 6603      Public            High          76
# 6604      Public          Medium          90
# 6606      Public          Medium          67
#
# [5198 rows x 3 columns]

# %% [markdown]
# # Q8 : How can you find the number of unique values in the Motivation_Level column of the Student_survey DataFrame?"

# %%
Student_survey.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
Student_survey['Motivation_Level'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0          Low
# 1          Low
# 2       Medium
# 3       Medium
# 4       Medium
#          ...
# 6602    Medium
# 6603    Medium
# 6604       Low
# 6605      High
# 6606    Medium
# Name: Motivation_Level, Length: 6607, dtype: object>

# %%
Student_survey.loc[(Student_survey['Hours_Studied']<10)
                   &(Student_survey['Motivation_Level']=='High')]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 74                4         100                 High                High
# 221               9          96               Medium              Medium
# 471               6          93               Medium              Medium
# 525               9          79               Medium                 Low
# 544               5          84               Medium              Medium
# 566               8          86               Medium                High
# 568               9          84                 High                 Low
# 671               8          94                 High                 Low
# 1151              7          74                  Low                High
# 1252              8          73                  Low              Medium
# 1325              8          80                 High                 Low
# 1425              8          88               Medium              Medium
# ...

# %% [markdown]
# # Q9:How can we filter the Student_survey DataFrame to display only the rows where the Attendance is above the average attendance?"

# %%
X=Student_survey['Attendance'].mean()
X
# Out:
# 79.97744816104132

# %%
Student_survey.loc[(X)<(Student_survey['Attendance'])]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# 5                19          88               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6599             30          94               Medium                 Low
# 6600             12          98               Medium                 Low
# 6601             20          83               Medium                 Low
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # Q10:How can we filter the Student_survey DataFrame to display only the rows where the Sleep_Hours is below the average sleep hours?

# %%
Y=Student_survey['Sleep_Hours'].mean()
Y
# Out:
# 7.029060087785682

# %%
Student_survey.loc[(Y)>(Student_survey['Sleep_Hours'])]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 2                24          98               Medium              Medium
# 4                19          92               Medium              Medium
# 6                29          84               Medium                 Low
# 7                25          78                  Low                High
# ...             ...         ...                  ...                 ...
# 6600             12          98               Medium                 Low
# 6601             20          83               Medium                 Low
# 6602             25          69                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # Q11:How can we filter the Student_survey DataFrame to display only the rows where the Hours_Studied is below the average hours studied?

# %%
Z=Student_survey['Hours_Studied'].mean()
Z
# Out:
# 19.975329196306948

# %%
AZ=Student_survey.loc[(Z)>(Student_survey['Hours_Studied'])]
AZ
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1                19          64                  Low              Medium
# 4                19          92               Medium              Medium
# 5                19          88               Medium              Medium
# 8                17          94               Medium                High
# 10               17          80                  Low                High
# ...             ...         ...                  ...                 ...
# 6597             16          91                 High              Medium
# 6598              9          87                  Low              Medium
# 6600             12          98               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # Q12:How can we filter the Student_survey DataFrame to display rows where students have a Low access to resources, a High family income, Yes internet access, and an Exam_Score below 67, or students who have an exam score below the average exam score?

# %%
Student_survey.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
Student_survey['Access_to_Resources'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
Student_survey['Internet_Access'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
Student_survey['Family_Income'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
H=Student_survey['Exam_Score'].mean()
H
# Out:
# 67.23565914938702

# %%
HA=Student_survey.loc[(H)>(Student_survey['Exam_Score'])]

# %%
Student_survey.loc[(Student_survey['Access_to_Resources']=='Low')
                  |(Student_survey['Family_Income']=='High')
                  &(Student_survey['Internet_Access']=='Yes')
                  &(Student_survey['Exam_Score']<67)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6                29          84               Medium                 Low
# 7                25          78                  Low                High
# 16               14          60               Medium                 Low
# 25               21          62                 High                 Low
# 26               13          91                  Low              Medium
# ...             ...         ...                  ...                 ...
# 6599             30          94               Medium                 Low
# 6600             12          98               Medium                 Low
# 6601             20          83               Medium                 Low
# 6604             20          90               Medium                 Low
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # Q13:How can we filter the Student_survey DataFrame to display rows where students have an Exam_Score greater than 75, Low family income, Low parental involvement, and more than 7 hours of sleep?

# %%
Student_survey['Family_Income'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
Student_survey['Parental_Involvement'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
Student_survey['Sleep_Hours'].mean()
# Out:
# 7.029060087785682

# %%
Student_survey.loc[(Student_survey['Exam_Score']>75)&
                  (Student_survey['Family_Income']=='Low')&
                  (Student_survey['Parental_Involvement']=='Low')&
                  (Student_survey['Sleep_Hours']>7)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 560              22          71                  Low                High
# 2421             27          90                  Low              Medium
# 2687             11          71                  Low              Medium
# 3924             18          87                  Low                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 560                         Yes            9               56
# 2421                         No            9               52
# 2687                        Yes            8               55
# 3924                         No            8               79
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 560              High             Yes                  1           Low
# 2421              Low              No                  2           Low
# 2687           Medium             Yes                  1           Low
# ...

# %% [markdown]
# # Q14:How can we filter the Student_survey DataFrame to display the Physical_Activity and Hours_Studied columns for students who have a physical activity rating of 4?

# %%
Student_survey['Physical_Activity'].unique()
# Out:
# array([3, 4, 2, 1, 5, 0, 6], dtype=int64)

# %%
Student_survey.loc[(Student_survey['Physical_Activity']==4)].loc[:,['Physical_Activity','Hours_Studied']]
# Out:
#       Physical_Activity  Hours_Studied
# 1                     4             19
# 2                     4             24
# 3                     4             29
# 4                     4             19
# 10                    4             17
# ...                 ...            ...
# 6588                  4             15
# 6593                  4             16
# 6594                  4              9
# 6601                  4             20
# 6606                  4             15
#
# [1575 rows x 2 columns]

# %% [markdown]
# # Q15:How can we filter the Student_survey DataFrame to display rows where the Parental_Education_Level is either College or Postgraduate, and the Exam_Score is below average?

# %%
Student_survey['Parental_Education_Level'].unique()
# Out:
# array(['High School', 'College', 'Postgraduate', nan], dtype=object)

# %%
Student_survey['Exam_Score'].mean()
# Out:
# 67.23565914938702

# %%
Student_survey.loc[(Student_survey['Parental_Education_Level']=='College')|
                  (Student_survey['Parental_Education_Level']=='Postgraduate')&
                  (Student_survey['Exam_Score']<67)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1                19          64                  Low              Medium
# 4                19          92               Medium              Medium
# 8                17          94               Medium                High
# 10               17          80                  Low                High
# 13                9          82               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6588             15          88                  Low              Medium
# 6589             22          90                  Low                High
# 6590             19          70               Medium              Medium
# 6593             16          75                 High                 Low
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # Q16:How can we filter the Student_survey DataFrame to display rows where students live Near and have an attendance below average, or live Far and have an attendance above average?

# %%
Student_survey['Distance_from_Home'].unique()
# Out:
# array(['Near', 'Moderate', 'Far', nan], dtype=object)

# %%
Student_survey['Attendance'].mean()
# Out:
# 79.97744816104132

# %%
Student_survey.loc[(Student_survey['Distance_from_Home']=='Near')&
                  (Student_survey['Attendance']<80)|
                  (Student_survey['Distance_from_Home']=='Far')&
                  (Student_survey['Attendance']>80)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 14               10          78               Medium                High
# 15               17          68               Medium              Medium
# 16               14          60               Medium                 Low
# 17               22          70                  Low              Medium
# 19               12          75               Medium                High
# ...             ...         ...                  ...                 ...
# 6593             16          75                 High                 Low
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # Q17:How can we get the count of each unique value in the School_Type column of the Student_survey DataFrame?"

# %%
Student_survey.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
Student_survey['School_Type'].value_counts()
# Out:
# School_Type
# Public     4598
# Private    2009
# Name: count, dtype: int64
