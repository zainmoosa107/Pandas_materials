# %%
import pandas as pd

# %% [markdown]
# - Rank: A unique integer identifier that ranks the video games based on a specific criterion (likely sales).
# - Name: The name of the video game.
# - Platform: The gaming platform on which the video game was released (e.g., PS4, Xbox One, PC).
# - Year: The year the game was released. This column has some missing values, with 16,327 non-null entries out of 16,598.
# - Genre: The genre of the video game (e.g., Action, Sports, RPG).
# - Publisher: The company that published the video game. There are a few missing values, with 16,540 non-null entries.
# - NA_Sales: Sales in North America, measured in millions of units.
# - EU_Sales: Sales in Europe, measured in millions of units.
# - JP_Sales: Sales in Japan, measured in millions of units.
# - Other_Sales: Sales in regions other than North America, Europe, and Japan, measured in millions of units.
# - Global_Sales: The total global sales of the video game, measured in millions of units.

# %%
games=pd.read_csv("E:\pandas.DA\PANDAS_Learning\za\Online_game.csv")
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
games.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
games['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000.,   nan, 1995., 2016., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
games.dropna(subset='Year',inplace=True)

# %%
games['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000., 1995., 2016., 1991., 1981., 1987., 1980.,
#        1983., 2020., 2017.])

# %%
games['Year']=games['Year'].astype('int64')

# %%
games['Year'].dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 games['Year'].dtype()
#
# TypeError: 'numpy.dtype[int64]' object is not callable

# %%
games.isnull().sum()
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       36
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %% [markdown]
# # 1: Top 5 best sale games in the data

# %%
top_5=games.sort_values(by='Global_Sales',ascending=False)

# %%
top_5.head(5)
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# # 2:Bottom 5 video game sales

# %%
bottom_5=games.sort_values(by='Global_Sales')
bottom_5.head(5)
# Out:
#         Rank                                             Name Platform  Year  \
# 16597  16600                                 Spirits & Spells      GBA  2003
# 16186  16189                                      BattleForge       PC  2009
# 16185  16188           Tantei Jinguuji Saburo: Hai to Diamond      PSP  2009
# 16184  16187  Fatal Fury: Battle Archives Volume 2 (JP sales)      PS2  2007
# 16183  16186                      Sakura-Sou no Pet na Kanojo      PSP  2013
#
#            Genre         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 16597   Platform           Wanadoo      0.01      0.00      0.00          0.0
# 16186   Strategy   Electronic Arts      0.00      0.01      0.00          0.0
# 16185  Adventure  Arc System Works      0.00      0.00      0.01          0.0
# 16184   Fighting      SNK Playmore      0.00      0.00      0.01          0.0
# 16183  Adventure    Kadokawa Games      0.00      0.00      0.01          0.0
#
#        Global_Sales
# ...

# %% [markdown]
# # 3: Which platform provides more game

# %%
games['Platform'].value_counts()
# Out:
# Platform
# DS      2133
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1235
# PSP     1197
# PS      1189
# PC       943
# GBA      811
# XB       803
# GC       542
# 3DS      500
# PSV      412
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %% [markdown]
# - TAKEAWAY: DS platform produced 2163 games

# %% [markdown]
# # 4: Games which is under the platform of Wii

# %%
games.loc[games['Platform']=='Wii']
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#        Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %% [markdown]
# # 5: No:of sales in a year

# %%
games['Year'].value_counts()
# Out:
# Year
# 2009    1431
# 2008    1428
# 2010    1259
# 2007    1202
# 2011    1139
# 2006    1008
# 2005     941
# 2002     829
# 2003     775
# 2004     763
# 2012     657
# 2015     614
# 2014     582
# 2013     546
# 2001     482
# 1998     379
# 2000     349
# 2016     344
# 1999     338
# 1997     289
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# 2017       3
# 2020       1
# Name: count, dtype: int64

# %% [markdown]
# - TAKEAWAY : In 2009 having a top sale of 1431 in online games

# %% [markdown]
# # 6:All  year sales

# %%
games.pivot_table(index='Year',values=['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales'],aggfunc=sum)
# Out:
#       EU_Sales  Global_Sales  JP_Sales  NA_Sales  Other_Sales
# Year
# 1980      0.67         11.38      0.00     10.59         0.12
# 1981      1.96         35.77      0.00     33.40         0.32
# 1982      1.65         28.86      0.00     26.92         0.31
# 1983      0.80         16.79      8.10      7.76         0.14
# 1984      2.10         50.36     14.27     33.28         0.70
# 1985      4.74         53.94     14.56     33.73         0.92
# 1986      2.84         37.07     19.81     12.50         1.93
# 1987      1.41         21.74     11.63      8.46         0.20
# 1988      6.59         47.22     15.76     23.87         0.99
# 1989      8.44         73.45     18.36     45.15         1.50
# 1990      7.63         49.39     14.88     25.46         1.40
# 1991      3.95         32.23     14.78     12.76         0.74
# 1992     11.71         76.16     28.91     33.87         1.65
# 1993      4.65         45.98     25.33     15.12         0.89
# ...

# %% [markdown]
# # 7: Games that having the  genre only sports and racing.There sales

# %%
games.loc[(games['Genre']=='Sports')|(games['Genre']=='Racing') ]
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 11        12                                     Mario Kart DS       DS  2005
# 13        14                                           Wii Fit      Wii  2007
# ...      ...                                               ...      ...   ...
# 16578  16581                     Outdoors Unleashed: Africa 3D      3DS  2011
# 16579  16582                                 PGA European Tour      N64  2000
# 16581  16584                                         Fit & Fun      Wii  2011
# 16587  16590                          Mezase!! Tsuri Master DS       DS  2009
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
#
# ...

# %% [markdown]
# # 8: Which country have more sales

# %%
games.pivot_table(index='Year',values=['NA_Sales','EU_Sales','JP_Sales','Other_Sales'],aggfunc=sum,margins=True,margins_name='Total')
# Out:
#        EU_Sales  JP_Sales  NA_Sales  Other_Sales
# Year
# 1980       0.67      0.00     10.59         0.12
# 1981       1.96      0.00     33.40         0.32
# 1982       1.65      0.00     26.92         0.31
# 1983       0.80      8.10      7.76         0.14
# 1984       2.10     14.27     33.28         0.70
# 1985       4.74     14.56     33.73         0.92
# 1986       2.84     19.81     12.50         1.93
# 1987       1.41     11.63      8.46         0.20
# 1988       6.59     15.76     23.87         0.99
# 1989       8.44     18.36     45.15         1.50
# 1990       7.63     14.88     25.46         1.40
# 1991       3.95     14.78     12.76         0.74
# 1992      11.71     28.91     33.87         1.65
# 1993       4.65     25.33     15.12         0.89
# 1994      14.88     33.99     28.15         2.20
# 1995      14.90     45.75     24.82         2.64
# 1996      47.26     57.44     86.76         7.69
# 1997      48.32     48.87     94.75         9.13
# ...

# %% [markdown]
# - TAKEAWAY: North America having most sales

# %% [markdown]
# # 9: Which of the games that have more than 10 sales in Japan

# %%
games.loc[games['JP_Sales']>10]
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4     11.27      8.89     10.22          1.0         31.37

# %% [markdown]
#  - TAKEAWAY : Only Pokemon Red/Pokemon Blue game which having a sales of 10.22 in Japan

# %% [markdown]
# # 10: Want to get the details that having the platform Wii and publisher Nintendo

# %%
games[(games['Platform']=='Wii')&(games['Publisher']=='Nintendo')]
# Out:
#         Rank                                         Name Platform  Year  \
# 0          1                                   Wii Sports      Wii  2006
# 2          3                               Mario Kart Wii      Wii  2008
# 3          4                            Wii Sports Resort      Wii  2009
# 7          8                                     Wii Play      Wii  2006
# 8          9                    New Super Mario Bros. Wii      Wii  2009
# ...      ...                                          ...      ...   ...
# 13314  13316                     Wii de Asobu Chibi-Robo!      Wii  2009
# 13523  13525  Minna ga Shuyaku no NHK Kouhaku Quiz Kassen      Wii  2009
# 14376  14379  Eyeshield 21: Field Saikyou no Senshi Tachi      Wii  2007
# 15991  15994                      Donkey Kong Jungle Beat      Wii  2008
# 16473  16476                              Captain Rainbow      Wii  2008
#
#               Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
#  - TAKEAWAY: There were 85 online games published by Nintendo in Wii platform

# %% [markdown]
# # 11:Top 10 games and corresponding sales .Who is publisher?

# %%
games.loc[0:10,['Name','Publisher','NA_Sales','EU_Sales','JP_Sales','Other_Sales']]
# Out:
#                          Name Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0                  Wii Sports  Nintendo     41.49     29.02      3.77
# 1           Super Mario Bros.  Nintendo     29.08      3.58      6.81
# 2              Mario Kart Wii  Nintendo     15.85     12.88      3.79
# 3           Wii Sports Resort  Nintendo     15.75     11.01      3.28
# 4    Pokemon Red/Pokemon Blue  Nintendo     11.27      8.89     10.22
# 5                      Tetris  Nintendo     23.20      2.26      4.22
# 6       New Super Mario Bros.  Nintendo     11.38      9.23      6.50
# 7                    Wii Play  Nintendo     14.03      9.20      2.93
# 8   New Super Mario Bros. Wii  Nintendo     14.59      7.06      4.70
# 9                   Duck Hunt  Nintendo     26.93      0.63      0.28
# 10                 Nintendogs  Nintendo      9.07     11.00      1.93
#
#     Other_Sales
# 0          8.46
# 1          0.77
# 2          3.31
# 3          2.96
# 4          1.00
# 5          0.58
# ...

# %% [markdown]
# - TAKEAWAY: Nintendo is best publisher who published top 10 rank games

# %% [markdown]
# # 12:In which genre the publisher 'Nintendo' published the most

# %%
genre_and_nintendo=games.loc[games['Publisher']=='Nintendo'].loc[:,['Genre','Publisher']]
genre_and_nintendo
# Out:
#               Genre Publisher
# 0            Sports  Nintendo
# 1          Platform  Nintendo
# 2            Racing  Nintendo
# 3            Sports  Nintendo
# 4      Role-Playing  Nintendo
# ...             ...       ...
# 16269        Action  Nintendo
# 16357        Puzzle  Nintendo
# 16456          Misc  Nintendo
# 16473     Adventure  Nintendo
# 16542          Misc  Nintendo
#
# [696 rows x 2 columns]

# %%
genre_and_nintendo.value_counts()
# Out:
# Genre         Publisher
# Platform      Nintendo     111
# Role-Playing  Nintendo     105
# Misc          Nintendo     100
# Action        Nintendo      78
# Puzzle        Nintendo      74
# Sports        Nintendo      55
# Racing        Nintendo      37
# Adventure     Nintendo      35
# Strategy      Nintendo      31
# Simulation    Nintendo      28
# Shooter       Nintendo      24
# Fighting      Nintendo      18
# Name: count, dtype: int64

# %% [markdown]
# - TAKEAWAY: In Platform genre Nintendo published the most about 111 games

# %% [markdown]
# # 13: Which is best game in 2007 and its rank in Depends on the whole year game sales data,global sales(in million units)

# %%
games.loc[games['Year']==2007].loc[:,['Rank','Name','Year','Global_Sales']]
# Out:
#         Rank                                               Name  Year  \
# 13        14                                            Wii Fit  2007
# 43        44                                             Halo 3  2007
# 48        49                                 Super Mario Galaxy  2007
# 70        71                     Call of Duty 4: Modern Warfare  2007
# 74        75                                     Mario Party DS  2007
# ...      ...                                                ...   ...
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!  2007
# 16558  16561                          Pro Evolution Soccer 2008  2007
# 16564  16567      Original Frisbee Disc Sports: Ultimate & Golf  2007
# 16573  16576                                Mini Desktop Racing  2007
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...  2007
#
#        Global_Sales
# 13            22.72
# 43            12.14
# 48            11.52
# 70             9.32
# ...

# %% [markdown]
# - TAKEAWAY:There are 1202 video games in 2007 in which 'Will Fit' having a top sales of 22.72 (million units).Its rank according to other year video games were 14

# %% [markdown]
# # 14:video games that having a global sales of 0.01

# %%
less_sales=games.loc[games['Global_Sales']==0.01].loc[:,['Name','Platform','Publisher']]
less_sales
# Out:
#                                                     Name Platform  \
# 15980                                              Turok       PC
# 15981                     Coven and Labyrinth of Refrain      PSV
# 15982  Super Battle For Money Sentouchuu: Kyuukyoku n...      3DS
# 15983                                   Dragon Zakura DS       DS
# 15984                             Chameleon: To Dye For!       DS
# ...                                                  ...      ...
# 16593                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594                      Men in Black II: Alien Escape       GC
# 16595   SCORE International Baja 1000: The Official Game      PS2
# 16596                                         Know How 2       DS
# 16597                                   Spirits & Spells      GBA
#
#                   Publisher
# 15980            Touchstone
# 15981  Nippon Ichi Software
# 15982    Namco Bandai Games
# 15983       Electronic Arts
# ...

# %% [markdown]
# - TAKEAWAY: There were 605 video games which having 0.01 Global sales

# %% [markdown]
# # 15: global sales of 0.01 which platform provides more games

# %%
less_sales['Platform'].value_counts()
# Out:
# Platform
# PC      102
# PSP      91
# DS       88
# PS2      67
# PSV      47
# X360     32
# GBA      31
# Wii      29
# PS3      27
# 3DS      23
# XB       15
# XOne     14
# PS4      11
# GC       11
# PS        8
# WiiU      6
# N64       2
# SNES      1
# Name: count, dtype: int64

# %% [markdown]
# - TAKEAWAY: PC Platform produces 102 games

# %% [markdown]
# # 16: Which are the video games that does not have sale in North America

# %%
no_sales_NA=games.loc[games['NA_Sales']==0.00].loc[:,['Name','NA_Sales']]
no_sales_NA
# Out:
#                                                     Name  NA_Sales
# 214                             Monster Hunter Freedom 3       0.0
# 338                                    Friend Collection       0.0
# 383                                     Monster Hunter 4       0.0
# 402    English Training: Have Fun Improving Your Skills!       0.0
# 426                 Dragon Quest VI: Maboroshi no Daichi       0.0
# ...                                                  ...       ...
# 16587                           Mezase!! Tsuri Master DS       0.0
# 16589  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...       0.0
# 16590  Eiyuu Densetsu: Sora no Kiseki Material Collec...       0.0
# 16595   SCORE International Baja 1000: The Official Game       0.0
# 16596                                         Know How 2       0.0
#
# [4439 rows x 2 columns]

# %%
no_sales_NA.nunique()
# Out:
# Name        4030
# NA_Sales       1
# dtype: int64

# %% [markdown]
# - TAKEAWAY: There were 4030 video games that have no sales in North America

# %% [markdown]
# # 17: Whether GB Platform is in top 10 video games

# %%
games.loc[games['Platform']=='GB'].loc[0:9,['Name','Platform']]
# Out:
#                        Name Platform
# 4  Pokemon Red/Pokemon Blue       GB
# 5                    Tetris       GB

# %% [markdown]
# - TAKEAWAY: There were two video games in the platform of GB in top 10 they were in rank 4,rank 5

# %% [markdown]
# # 18:In top 10 which video game genre is going more

# %%
Top_10_genre=games.loc[0:9,['Rank','Name','Genre']]
Top_10_genre
# Out:
#    Rank                       Name         Genre
# 0     1                 Wii Sports        Sports
# 1     2          Super Mario Bros.      Platform
# 2     3             Mario Kart Wii        Racing
# 3     4          Wii Sports Resort        Sports
# 4     5   Pokemon Red/Pokemon Blue  Role-Playing
# 5     6                     Tetris        Puzzle
# 6     7      New Super Mario Bros.      Platform
# 7     8                   Wii Play          Misc
# 8     9  New Super Mario Bros. Wii      Platform
# 9    10                  Duck Hunt       Shooter

# %%
Top_10_genre['Genre'].value_counts()
# Out:
# Genre
# Platform        3
# Sports          2
# Racing          1
# Role-Playing    1
# Puzzle          1
# Misc            1
# Shooter         1
# Name: count, dtype: int64

# %% [markdown]
# - TAKEAWAY: UnderPlatform genre having 3 video games in top 10 video games

# %% [markdown]
# # 19:Who published the most video games

# %%
games['Publisher'].value_counts()
# Out:
# Publisher
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
#                                 ...
# Detn8 Games                        1
# Pow                                1
# Navarre Corp                       1
# MediaQuest                         1
# UIG Entertainment                  1
# Name: count, Length: 576, dtype: int64

# %% [markdown]
# - TAKEAWAY: Electronic Arts published 1339 video games

# %% [markdown]
# # 20: which of the video games,platform and genre published by 'Wanadoo'

# %%
games.loc[games['Publisher']=='Wanadoo'].loc[:,['Name','Genre']]
# Out:
#                                  Name     Genre
# 4238   Rygar: The Legendary Adventure    Action
# 9016                      Fatal Frame    Action
# 15675                Spirits & Spells  Platform
# 15734             Top Gear RPM Tuning    Racing
# 16597                Spirits & Spells  Platform

# %% [markdown]
# - TAKEAWAY: Wanadoo published 5 video games which is ranked higher that 1000
